# %%
import pandas as pd

# 프롬프트 데이터 정의
data = {
    "Category": ["Whoosh"] * 10 + ["Ambience"] * 10 + ["Footsteps"] * 10 + ["Weather"] * 10 + ["Animals"] * 10 +
               ["Technology"] * 10 + ["Cartoon"] * 10 + ["Water"] * 10 + ["Foley"] * 10 + ["Storytelling"] * 10 +
               ["Crowds"] * 10 + ["Laser"] * 10,
    "Prompt": [
    "The whoosh sound of a fast object passing by, creating a sharp whoosh.",
    "The whoosh sound of a sword swinging rapidly through the air.",
    "The whoosh sound of a whip cracking sharply in the open air.",
    "The whoosh sound of a strong gust of wind whooshing through trees.",
    "The whoosh sound of a race car speeding past on a track.",
    "The whoosh sound of a bullet rapidly passing by overhead.",
    "The whoosh sound of a paper airplane gliding smoothly in the air.",
    "The whoosh sound of a boomerang spinning and returning.",
    "The whoosh sound of an arrow swiftly flying towards a target.",
    "The whoosh sound of a superhero flying at high speed.",
    "The sound of a bustling city street during rush hour.",
    "The sound of a calm beach with gentle waves and distant seagulls.",
    "The sound of a busy coffee shop with background chatter.",
    "The sound of a forest at night with crickets chirping.",
    "The sound of a tranquil mountain stream with water flowing.",
    "The sound of a crowded marketplace with various vendors.",
    "The sound of a train station with announcements and trains arriving.",
    "The sound of a thunderstorm brewing in the distance.",
    "The sound of a peaceful countryside with birds singing.",
    "The sound of a lively schoolyard during recess.",
    "The sound of footsteps walking on crunchy snow.",
    "The sound of someone running on a gravel path.",
    "The sound of high heels clicking on a marble floor.",
    "The sound of boots trekking through a muddy trail.",
    "The sound of bare feet walking on a sandy beach.",
    "The sound of shoes squeaking on a basketball court.",
    "The sound of children's footsteps racing in a hallway.",
    "The sound of a person tiptoeing in a quiet house.",
    "The sound of footsteps ascending a wooden staircase.",
    "The sound of someone pacing on a creaky floorboard.",
    "The sound of a gentle rain falling on a rooftop.",
    "The sound of a fierce thunderstorm with loud claps of thunder.",
    "The sound of wind howling during a blizzard.",
    "The sound of hailstones pelting a window.",
    "The sound of a tornado swirling with debris.",
    "The sound of leaves rustling in a gentle autumn breeze.",
    "The sound of a heavy downpour in a tropical rainforest.",
    "The sound of distant thunder rumbling in a summer evening.",
    "The sound of a snowstorm with strong gusts of wind.",
    "The sound of a foghorn in dense fog at sea.",
    "The sound of a lion roaring in the savanna.",
    "The sound of a flock of birds taking off in unison.",
    "The sound of a dog barking excitedly in a yard.",
    "The sound of a cat purring contentedly on a windowsill.",
    "The sound of a horse galloping on a dirt road.",
    "The sound of dolphins chattering underwater.",
    "The sound of a wolf howling at the moon.",
    "The sound of frogs croaking in a wetland.",
    "The sound of a snake hissing in the grass.",
    "The sound of a bear growling in the forest.",
    "The sound of a computer starting up with a series of beeps.",
    "The sound of a smartphone receiving multiple notifications.",
    "The sound of a printer printing a long document.",
    "The sound of a drone buzzing overhead.",
    "The sound of a digital camera shutter clicking.",
    "The sound of a robotic arm moving in a factory.",
    "The sound of an old television turning on and static noise.",
    "The sound of a microwave beeping when the timer ends.",
    "The sound of a washing machine on its spin cycle.",
    "The sound of a virtual assistant responding to a command.",
    "The sound of a cartoon character slipping and falling.",
    "The sound of exaggerated cartoon eating noises.",
    "The sound of a cartoon rocket blasting off.",
    "The sound of a cartoon animal making a humorous squeak.",
    "The sound of a cartoon character running with rapid foot taps.",
    "The sound of a cartoon magic wand with sparkly effects.",
    "The sound of a cartoon car honking with a funny tone.",
    "The sound of a cartoon character jumping with a boing sound.",
    "The sound of a cartoon explosion with a comical bang.",
    "The sound of a cartoon bird tweeting melodically.",
    "The sound of waves crashing against the shore.",
    "The sound of a stream bubbling over rocks.",
    "The sound of raindrops hitting a pond's surface.",
    "The sound of a water fountain in a public park.",
    "The sound of a rowboat gently rowing ona lake.",
    "The sound of a waterfall cascading down a cliff.",
    "The sound of someone swimming in a pool.",
    "The sound of water dripping from a leaky faucet.",
    "The sound of a kettle boiling and whistling.",
    "The sound of an underwater submarine sonar ping.",
    "The sound of keys jangling in someone's hand.",
    "The sound of a book being opened and pages flipping.",
    "The sound of a jacket zipper being zipped up.",
    "The sound of a match being struck and lighting a candle.",
    "The sound of dishes clinking in a kitchen.",
    "The sound of a suitcase being dragged across the floor.",
    "The sound of curtains being drawn open.",
    "The sound of a broom sweeping a dusty floor.",
    "The sound of a backpack being unzipped.",
    "The sound of someone typing on a keyboard.",
    "The sound of a mysterious door creaking open in an old house.",
    "The sound of footsteps approaching in a suspenseful scene.",
    "The sound of a ghostly whisper in a haunted room.",
    "The sound of a character gasping in shock.",
    "The sound of a dramatic musical sting during a reveal.",
    "The sound of leaves rustling as someone hides in a forest.",
    "The sound of a clock ticking ominously in a thriller.",
    "The sound of a sword being drawn in an epic battle.",
    "The sound of a magical portal opening in a fantasy world.",
    "The sound of a detective's footsteps in a noir film.",
    "The sound of a crowd cheering at a sports event.",
    "The sound of people clapping and applauding in a theater.",
    "The sound of a busy urban street with pedestrian chatter.",
    "The sound of a festival with music and crowd noises.",
    "The sound of a protest with chants and shouts.",
    "The sound of an audience laughing during a comedy show.",
    "The sound of a crowded restaurant with conversation and utensils.",
    "The sound of a train station with announcements and foot traffic.",
    "The sound of a marketplace with vendors calling out.",
    "The sound of a concert crowd cheering for an encore.",
    "The sound of a laser gun firing in a sci-fi battle.",
    "The sound of a laser beam cutting through metal.",
    "The sound of a futuristic door being unlocked by a laser.",
    "The sound of a laser printer printing a document.",
    "The sound of a laser scanning a barcode.",
    "The sound of a laser security alarm being triggered.",
    "The sound of a laser light show with pulsating beams.",
    "The sound of a laser sword clashing in a duel.",
    "The sound of a laser-guided missile locking onto its target.",
    "The sound of a high-tech laser operating in a lab."
]
}

# DataFrame 생성
df = pd.DataFrame(data)

# CSV 파일로 저장
csv_file_path = "csv_files/sound_effect_prompts.csv"
df.to_csv(csv_file_path, index=False)

# 파일 경로 출력
csv_file_path
# Out:
# 'csv_files/sound_effect_prompts.csv'
